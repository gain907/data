# %% [markdown]
# #[중간평가]

# %% [markdown]
# ### KNN 모델을 이용해서 BMI데이터 학습
# - BMI 데이터 구성
#  - 특성(문제): 성별,몸무게,키
#  - 특성(답지): 0,1,2,3,4,5
#    - 0 - Extremely Weak
#    - 1 - Weak
#    - 2 - Normal
#    - 3 - Overweight
#    - 4 - Obesity
#    - 5 - Extreme Obesity
#  - 데이터 수: 500개

# %% [markdown]
# ### 이 데이터의 특징
#  - 문제 데이터 : Gender	Height	Weight
#  - 답지 데이터 : Index

# %% [markdown]
# ### [문제1] pandas, numpy 가져오기
#  - pandas
#  - numpy

# %%
#[정답]

# %% [markdown]
# ### 데이터 가져오기

# %%
bmi_df = pd.read_csv('/content/drive/MyDrive/폴리텍전남캠퍼스/data/bmi.csv')
bmi_df

# %% [markdown]
# ### [문제2] iloc를 이용해서  train, test 데이터 나누기
#  - train = 400개
#  - test = 100개

# %% [markdown]
# ###[문제3]
#  - bmi_df 데이터의 크기 확인
#  - train 데이터의 크기 확인
#  - test 데이터의 크기 확인

# %% [markdown]
# ### [문제4] train,test 데이터 문제,답지 나누기
# - X_train(문제)
# - y_train(답지)
# - X_test(문제)
# - y_test(답지)

# %% [markdown]
# ### [문제5] train,test 데이터 문제,답지 크기 확인

# %% [markdown]
# ### 모델 생성

# %%
# 머신러닝 모델 만들기  KNN 모델 불러오기
from sklearn.neighbors import KNeighborsClassifier
# 모델 생성해서 새로운 변수에 넣어주세요
knn_model = KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# ###[문제6] 모델 학습
#  - train 데이터의 문제 답지를 가지고 학습시켜주세요

# %%
# fit 함수를 사용하세요

# %% [markdown]
# ###[문제7] 모델 예측
# - test데이터를 가지고 예측해 주세요

# %%
# predict 함수를 사용하세요

# %% [markdown]
# ###[문제8] 모델을 평가해 주세요
# - ? 표에 알맞은 변수를 넣어주세요

# %%
# 모델 평가
from sklearn.metrics import accuracy_score
# accuracy_score(예측값,실제값)
score = accuracy_score(?,?)
score
